# %% [markdown]
# <a href="https://colab.research.google.com/github/Shenbagapriya24/Assignments/blob/main/Pandas_Assign1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import the pandas library
#Read the data company.csv in pandas

import pandas as pd
url = 'https://raw.githubusercontent.com/balaji2v/Inceptez_Batch19/main/company.csv'
df = pd.read_csv(url)
print(df)
# Out:
#      Company   Age  Salary     Place Country
# 0        TCS  20.0     NaN   Chennai   India
# 1    Infosys  30.0     NaN    Mumbai   India
# 2        TCS  35.0  2300.0  Calcutta   India
# 3    Infosys  40.0  3000.0     Delhi   India
# 4        TCS  23.0  4000.0    Mumbai   India
# ..       ...   ...     ...       ...     ...
# 144  Infosys  22.0  8787.0  Calcutta   India
# 145  Infosys  44.0  4034.0     Delhi   India
# 146      TCS  33.0  5034.0    Mumbai   India
# 147  Infosys  22.0  8202.0    Cochin   India
# 148      NaN   NaN     NaN       NaN     NaN
#
# [149 rows x 5 columns]

# %%
#Find the dimension of given data
size = df.size
shape = df.shape
df_ndim = df.ndim
series_ndim = df["Salary"].ndim  #size of series
  
# printing size and shape
print("Size = {}\nShape ={}".
format(size, shape))
  
# printing ndim
print("ndim of dataframe = {}\nndim of series ={}".
format(df_ndim, series_ndim))
# Out:
# Size = 745
# Shape =(149, 5)
# ndim of dataframe = 2
# ndim of series =1

# %%
#List down all the columns in data frame
#print(df.columns) #with datatype
print(df.columns.tolist()) #gives in a list
# Out:
# ['Company', 'Age', 'Salary', 'Place', 'Country']

# %%
#List the top 10 rows in datframe
print(df.head(10))
# Out:
#    Company   Age  Salary     Place Country
# 0      TCS  20.0     NaN   Chennai   India
# 1  Infosys  30.0     NaN    Mumbai   India
# 2      TCS  35.0  2300.0  Calcutta   India
# 3  Infosys  40.0  3000.0     Delhi   India
# 4      TCS  23.0  4000.0    Mumbai   India
# 5  Infosys   NaN  5000.0  Calcutta   India
# 6      TCS   NaN  6000.0   Chennai   India
# 7  Infosys  23.0  7000.0    Mumbai   India
# 8      TCS  34.0  8000.0  Calcutta   India
# 9      CTS  45.0  9000.0     Delhi   India

# %%
#List the last 15 rows in datframe
print(df.tail(15))
# Out:
#                        Company   Age  Salary      Place Country
# 134  Tata Consultancy Services  31.0  8345.0     Mumbai   India
# 135                        CTS  40.0  9284.0   Calcutta   India
# 136                        NaN   NaN     NaN      Delhi   India
# 137                        CTS  31.0  2034.0     Mumbai   India
# 138                        CTS  44.0  3033.0     Cochin   India
# 139                 Congnizant  22.0  2934.0      Noida   India
# 140                    Infosys  44.0  4034.0  Hyderabad   India
# 141                        TCS  33.0  5034.0   Calcutta   India
# 142            Infosys Pvt Lmt  22.0  8202.0     Mumbai   India
# 143                        TCS  33.0  9024.0   Calcutta   India
# 144                    Infosys  22.0  8787.0   Calcutta   India
# 145                    Infosys  44.0  4034.0      Delhi   India
# 146                        TCS  33.0  5034.0     Mumbai   India
# 147                    Infosys  22.0  8202.0     Cochin   India
# 148                        NaN   NaN     NaN        NaN     NaN

# %%
#Find the number of rows in dataframe
print("Number of rows:" , df.shape[0])
print("Number of columns:" , df.shape[1])
# Out:
# Number of rows: 149
# Number of columns: 5

# %%
#Check the information of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  140 non-null    object
#  1   Age      130 non-null    float64
#  2   Salary   124 non-null    float64
#  3   Place    134 non-null    object
#  4   Country  148 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 5.9+ KB

# %%
#Check the basic Statistics of Dataframe. Give your inference from the stats
df.describe(include = 'all')
# Out:
#        Company         Age       Salary   Place Country
# count      140  130.000000   124.000000     134     148
# unique       6         NaN          NaN      11       1
# top        TCS         NaN          NaN  Mumbai   India
# freq        53         NaN          NaN      37     148
# mean       NaN   30.484615  5312.467742     NaN     NaN
# std        NaN   11.096640  2573.764683     NaN     NaN
# min        NaN    0.000000  1089.000000     NaN     NaN
# 25%        NaN   22.000000  3030.000000     NaN     NaN
# 50%        NaN   32.500000  5000.000000     NaN     NaN
# 75%        NaN   37.750000  8000.000000     NaN     NaN
# max        NaN   54.000000  9876.000000     NaN     NaN

# %%
#Retrieve 20 to 100 rows and Company and age usig iloc
df.loc[20:101,['Company','Age']]
# Out:
#      Company   Age
# 20       TCS  37.0
# 21   Infosys  50.0
# 22       TCS  21.0
# 23   Infosys   NaN
# 24       TCS   NaN
# ..       ...   ...
# 97   Infosys  22.0
# 98       TCS  33.0
# 99       CTS  44.0
# 100      CTS  22.0
# 101      CTS   0.0
#
# [82 rows x 2 columns]

# %%
#Retrieve 20 to 100 rows and Company and age usig loc

df.iloc[20:101,0:2]
# Out:
#      Company   Age
# 20       TCS  37.0
# 21   Infosys  50.0
# 22       TCS  21.0
# 23   Infosys   NaN
# 24       TCS   NaN
# ..       ...   ...
# 96       TCS   NaN
# 97   Infosys  22.0
# 98       TCS  33.0
# 99       CTS  44.0
# 100      CTS  22.0
#
# [81 rows x 2 columns]

# %%
#Chage the data in 100 row and Place as 'Noida'
print(df.loc[100,'Place'])
df.loc[100,'Place'] = 'Noida'
print(df.loc[100,'Place'])
# Out:
# Cochin
# Noida

# %%
#Change the column 'Place' to 'City'
df.rename(columns = {'Place' : 'City'},inplace = 'True')
print(df.columns)
# Out:
# Index(['Company', 'Age', 'Salary', 'City', 'Country'], dtype='object')

# %%
#List down the unique data in each columns and find length of unique data
for col in df:
    print("Count of Unique values in", col, df[col].nunique(dropna=False))
    print("Unique values in" , col, df[col].unique())
# Out:
# Count of Unique values in Company 7
# Unique values in Company ['TCS' 'Infosys' 'CTS' nan 'Tata Consultancy Services' 'Congnizant'
#  'Infosys Pvt Lmt']
# Count of Unique values in Age 30
# Unique values in Age [20. 30. 35. 40. 23. nan 34. 45. 18. 22. 32. 37. 50. 21. 46. 36. 26. 41.
#  24. 25. 43. 19. 38. 51. 31. 44. 33. 17.  0. 54.]
# Count of Unique values in Salary 41
# Unique values in Salary [  nan 2300. 3000. 4000. 5000. 6000. 7000. 8000. 9000. 1089. 1234. 3030.
#  3045. 3184. 4824. 5835. 7084. 8943. 8345. 9284. 9876. 2034. 7654. 2934.
#  4034. 5034. 8202. 9024. 4345. 6544. 6543. 3234. 4324. 5435. 5555. 8787.
#  3454. 5654. 5009. 5098. 3033.]
# Count of Unique values in City 12
# Unique values in City ['Chennai' 'Mumbai' 'Calcutta' 'Delhi' 'Podicherry' 'Cochin' nan 'Noida'
#  'Hyderabad' 'Bhopal' 'Nagpur' 'Pune']
# Count of Unique values in Country 2
# Unique values in Country ['India' nan]

# %%
#Rename all the possible labels of column in Company as three labels TCS CTS Infosys
import numpy as np
label = ['TCS','CTS','Infosys']
df['Company'] = np.random.choice(list(label),len(df))
df
# Out:
#      Company   Age  Salary      City Country
# 0        TCS  20.0     NaN   Chennai   India
# 1        TCS  30.0     NaN    Mumbai   India
# 2        CTS  35.0  2300.0  Calcutta   India
# 3    Infosys  40.0  3000.0     Delhi   India
# 4        TCS  23.0  4000.0    Mumbai   India
# ..       ...   ...     ...       ...     ...
# 144      CTS  22.0  8787.0  Calcutta   India
# 145  Infosys  44.0  4034.0     Delhi   India
# 146      CTS  33.0  5034.0    Mumbai   India
# 147  Infosys  22.0  8202.0    Cochin   India
# 148  Infosys   NaN     NaN       NaN     NaN
#
# [149 rows x 5 columns]

# %%
#Check how many duplicated data is there?
print(df.duplicated().sum())
print(df[df.duplicated()])
# Out:
# 3
#      Company   Age  Salary      City Country
# 144      CTS  22.0  8787.0  Calcutta   India
# 145  Infosys  44.0  4034.0     Delhi   India
# 147  Infosys  22.0  8202.0    Cochin   India

# %%
#Remove all duplicated rowise data
df = df.drop_duplicates()
df
# Out:
#      Company   Age  Salary      City Country
# 0        TCS  20.0     NaN   Chennai   India
# 1        TCS  30.0     NaN    Mumbai   India
# 2        CTS  35.0  2300.0  Calcutta   India
# 3    Infosys  40.0  3000.0     Delhi   India
# 4        TCS  23.0  4000.0    Mumbai   India
# ..       ...   ...     ...       ...     ...
# 141      TCS  33.0  5034.0  Calcutta   India
# 142  Infosys  22.0  8202.0    Mumbai   India
# 143  Infosys  33.0  9024.0  Calcutta   India
# 146      CTS  33.0  5034.0    Mumbai   India
# 148  Infosys   NaN     NaN       NaN     NaN
#
# [146 rows x 5 columns]

# %%
#Remove the column 'Country'
df.drop(['Country'], axis=1, inplace = True)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#      Company   Age  Salary      City
# 0        TCS  20.0     NaN   Chennai
# 1        TCS  30.0     NaN    Mumbai
# 2        CTS  35.0  2300.0  Calcutta
# 3    Infosys  40.0  3000.0     Delhi
# 4        TCS  23.0  4000.0    Mumbai
# ..       ...   ...     ...       ...
# 141      TCS  33.0  5034.0  Calcutta
# 142  Infosys  22.0  8202.0    Mumbai
# 143  Infosys  33.0  9024.0  Calcutta
# 146      CTS  33.0  5034.0    Mumbai
# 148  Infosys   NaN     NaN       NaN
#
# [146 rows x 4 columns]

# %%
#Remove the row number 137
df.drop([137], axis=0, inplace=True)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#      Company   Age  Salary      City
# 0        TCS  20.0     NaN   Chennai
# 1        TCS  30.0     NaN    Mumbai
# 2        CTS  35.0  2300.0  Calcutta
# 3    Infosys  40.0  3000.0     Delhi
# 4        TCS  23.0  4000.0    Mumbai
# ..       ...   ...     ...       ...
# 141      TCS  33.0  5034.0  Calcutta
# 142  Infosys  22.0  8202.0    Mumbai
# 143  Infosys  33.0  9024.0  Calcutta
# 146      CTS  33.0  5034.0    Mumbai
# 148  Infosys   NaN     NaN       NaN
#
# [145 rows x 4 columns]

# %%
#Find number of each labels in Company

df['Company'].value_counts()
# Out:
# CTS        57
# Infosys    49
# TCS        39
# Name: Company, dtype: int64

# %%
#Find number of each labels in City
df['City'].value_counts()
# Out:
# Mumbai        36
# Calcutta      32
# Chennai       14
# Delhi         13
# Cochin        11
# Noida          9
# Hyderabad      8
# Podicherry     3
# Pune           2
# Bhopal         1
# Nagpur         1
# Name: City, dtype: int64

# %%
#Find Number of Null Values in each column
df.isna().sum()
# Out:
# Company     0
# Age        19
# Salary     25
# City       15
# dtype: int64

# %%
#Remove all Null values in Salary
df.dropna(subset = ["Salary"])
# Out:
#      Company   Age  Salary       City
# 2        CTS  35.0  2300.0   Calcutta
# 3    Infosys  40.0  3000.0      Delhi
# 4        TCS  23.0  4000.0     Mumbai
# 5        TCS   NaN  5000.0   Calcutta
# 6        TCS   NaN  6000.0    Chennai
# ..       ...   ...     ...        ...
# 140  Infosys  44.0  4034.0  Hyderabad
# 141      TCS  33.0  5034.0   Calcutta
# 142  Infosys  22.0  8202.0     Mumbai
# 143  Infosys  33.0  9024.0   Calcutta
# 146      CTS  33.0  5034.0     Mumbai
#
# [120 rows x 4 columns]

# %%
#Replace the Null values in Comapany with mode
df['Company'].fillna(df['Company'].mode()[0], inplace = True)
print(df)
# Out:
#      Company   Age  Salary      City
# 0        TCS  20.0     NaN   Chennai
# 1        TCS  30.0     NaN    Mumbai
# 2        CTS  35.0  2300.0  Calcutta
# 3    Infosys  40.0  3000.0     Delhi
# 4        TCS  23.0  4000.0    Mumbai
# ..       ...   ...     ...       ...
# 141      TCS  33.0  5034.0  Calcutta
# 142  Infosys  22.0  8202.0    Mumbai
# 143  Infosys  33.0  9024.0  Calcutta
# 146      CTS  33.0  5034.0    Mumbai
# 148  Infosys   NaN     NaN       NaN
#
# [145 rows x 4 columns]
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
#Replace the null value in Salary with median
df['Salary'].fillna(df['Salary'].median(), inplace=True)
print(df)
# Out:
#      Company   Age  Salary      City
# 0        TCS  20.0  5000.0   Chennai
# 1        TCS  30.0  5000.0    Mumbai
# 2        CTS  35.0  2300.0  Calcutta
# 3    Infosys  40.0  3000.0     Delhi
# 4        TCS  23.0  4000.0    Mumbai
# ..       ...   ...     ...       ...
# 141      TCS  33.0  5034.0  Calcutta
# 142  Infosys  22.0  8202.0    Mumbai
# 143  Infosys  33.0  9024.0  Calcutta
# 146      CTS  33.0  5034.0    Mumbai
# 148  Infosys   NaN  5000.0       NaN
#
# [145 rows x 4 columns]
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
#Replace the null value in age with mean
df['Age'].fillna(df['Age'].mean(), inplace=True)
print(df)
# Out:
#      Company        Age  Salary      City
# 0        TCS  20.000000  5000.0   Chennai
# 1        TCS  30.000000  5000.0    Mumbai
# 2        CTS  35.000000  2300.0  Calcutta
# 3    Infosys  40.000000  3000.0     Delhi
# 4        TCS  23.000000  4000.0    Mumbai
# ..       ...        ...     ...       ...
# 141      TCS  33.000000  5034.0  Calcutta
# 142  Infosys  22.000000  8202.0    Mumbai
# 143  Infosys  33.000000  9024.0  Calcutta
# 146      CTS  33.000000  5034.0    Mumbai
# 148  Infosys  30.507937  5000.0       NaN
#
# [145 rows x 4 columns]
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
#Filter the data with age>40 and Salary<5000
df.loc[(df.Age>40) & (df.Salary<5000)]
# Out:
#      Company   Age  Salary       City
# 21       CTS  50.0  3184.0      Delhi
# 32   Infosys  45.0  4034.0   Calcutta
# 39       TCS  41.0  3000.0     Mumbai
# 50   Infosys  41.0  3000.0    Chennai
# 57   Infosys  51.0  3184.0  Hyderabad
# 68       CTS  43.0  4034.0     Mumbai
# 75   Infosys  44.0  3000.0     Cochin
# 86       TCS  41.0  3000.0      Delhi
# 93       TCS  54.0  3184.0     Mumbai
# 104  Infosys  44.0  4034.0      Delhi
# 122      TCS  44.0  3234.0     Mumbai
# 129      CTS  50.0  3184.0   Calcutta
# 138  Infosys  44.0  3033.0     Cochin
# 140  Infosys  44.0  4034.0  Hyderabad

# %%
#Draw the pie chart for place and Company
a = df.Company.value_counts().plot(kind = 'pie')

# %%
b = df.City.value_counts().plot(kind = 'pie')

# %%
#Find the mean age with repective to the Company
X = df['Company'].unique()
for col in X:
  print("Mean age wrt ", col,": ", df.loc[df['Company'] == col, 'Age'].mean())
# Out:
# Mean age wrt  TCS :  30.552706552706557
# Mean age wrt  CTS :  30.421888053467
# Mean age wrt  Infosys :  30.57240038872692

# %%
#Draw an histogram chart for age, Salary
df.hist(['Age','Salary'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f22024da1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f22024a17d0>]],
#       dtype=object)

# %%
#Find the mean, count, median of salary with repective to the place
X = df['City'].unique()
for pla in X:
  print("WRT {} , Mean {} , Median {} ".format(pla,df.loc[df['City'] == pla, 'Age'].mean(),df.loc[df['City'] == pla, 'Age'].median()))
df.groupby('City')['Salary'].count()
# Out:
# WRT Chennai , Mean 29.145124716553287 , Median 30.50793650793651
# WRT Mumbai , Mean 29.278659611992946 , Median 30.50793650793651
# WRT Calcutta , Mean 28.813492063492063 , Median 30.50793650793651
# WRT Delhi , Mean 34.885225885225886 , Median 35.0
# WRT Podicherry , Mean 22.333333333333332 , Median 23.0
# WRT Cochin , Mean 31.365079365079364 , Median 32.0
# WRT nan , Mean nan , Median nan
# WRT Noida , Mean 29.88888888888889 , Median 32.0
# WRT Hyderabad , Mean 39.31349206349206 , Median 39.5
# WRT Bhopal , Mean 26.0 , Median 26.0
# WRT Nagpur , Mean 32.0 , Median 32.0
# WRT Pune , Mean 32.5 , Median 32.5
# City
# Bhopal         1
# Calcutta      32
# Chennai       14
# Cochin        11
# Delhi         13
# Hyderabad      8
# Mumbai        36
# Nagpur         1
# Noida          9
# Podicherry     3
# Pune           2
# Name: Salary, dtype: int64
